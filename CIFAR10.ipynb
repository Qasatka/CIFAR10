# %% [markdown]
# <a href="https://colab.research.google.com/github/Qasatka/CIFAR10/blob/main/CIFAR10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importing the necessary modules
import numpy as np
from keras.models import Sequential
from keras.layers import Conv2D, Dropout, Dense, MaxPooling2D
from keras.layers import BatchNormalization, Flatten, Activation
from keras.optimizers import Adam
from keras.utils import to_categorical
from keras.datasets import cifar10

# %%
# Downloading and pre-processing dataset
(X_train, Y_train), (X_test, Y_test) = cifar10.load_data()

# Normalizing
X_train = X_train/255
X_test = X_test/255
X_validation, X_test = np.split(X_test, 2)
# One-Hot-Encoding
Y_train = to_categorical(Y_train,10)
Y_validation, Y_test = np.split(to_categorical(Y_test), 2)

# %%
# Build the neural network using Keras
model = Sequential()
# CONV => RELU => CONV => RELU => POOL => DROPOUT
model.add(Conv2D(32, (3, 3), padding='same'))
model.add(Activation('relu'))
model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

# CONV => RELU => CONV => RELU => POOL => DROPOUT
model.add(Conv2D(64, (3, 3), padding='same'))
model.add(Activation('relu'))
model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

# FLATTERN => DENSE => RELU => DROPOUT
model.add(Flatten())
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dropout(0.5))
# a softmax classifier
model.add(Dense(10))
model.add(Activation('softmax'))

# %%
# Compiling the model of our neural network
model.compile(loss='categorical_crossentropy',
              optimizer=Adam(),
              metrics=['accuracy'])

# %%
# Fitting the model to check its performance
history = model.fit(X_train, Y_train,
                    validation_data=(X_validation, Y_validation),
                    epochs=100, batch_size=32)
# Out:
# Epoch 1/100
# 1563/1563 [==============================] - 17s 7ms/step - loss: 1.4898 - accuracy: 0.4539 - val_loss: 1.0922 - val_accuracy: 0.6078
# Epoch 2/100
# 1563/1563 [==============================] - 9s 6ms/step - loss: 1.0830 - accuracy: 0.6149 - val_loss: 0.9038 - val_accuracy: 0.6770
# Epoch 3/100
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.9375 - accuracy: 0.6681 - val_loss: 0.8578 - val_accuracy: 0.6962
# Epoch 4/100
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.8474 - accuracy: 0.7006 - val_loss: 0.7488 - val_accuracy: 0.7376
# Epoch 5/100
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.7825 - accuracy: 0.7269 - val_loss: 0.7296 - val_accuracy: 0.7476
# Epoch 6/100
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.7432 - accuracy: 0.7388 - val_loss: 0.7168 - val_accuracy: 0.7516
# Epoch 7/100
# ...
